# %% [markdown]
# <a href="https://colab.research.google.com/github/Sokolov-AA/ML_Study/blob/main/PlatesBaselineKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# from google.colab import files

# uploaded = files.upload()

# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))
  
# # Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c platesv2
# !unzip platesv2.zip
# !unzip plates.zip

# !mv /content/plates/test /content/plates/unknown
# !mkdir /content/plates/test
# !mv /content/plates/unknown /content/plates/test/unknown

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory

print("TensorFlow verison:", tf.__version__)
# Out:
# TensorFlow verison: 2.8.2

# %%
image = tf.io.read_file('/content/plates/test/unknown/0100.jpg')
image = tf.image.decode_jpeg(image, channels=3)
print(image.shape)
input_shape = image.shape
# Out:
# (256, 341, 3)

# %%
seed = 42
batch_size=8

ds_train_ = image_dataset_from_directory(
    '/content/plates/train/',
    labels='inferred',
    label_mode='binary',
    image_size=[256, 341],
    interpolation='nearest',
    subset="training",
    validation_split=0.2,
    seed=42,
    batch_size=batch_size,
    shuffle=True)

ds_valid_ = image_dataset_from_directory(
    '/content/plates/train/',
    labels='inferred',
    label_mode='binary',
    image_size=[256, 341],
    interpolation='nearest',
    subset="validation",
    validation_split=0.2,
    seed=42,
    batch_size=batch_size,
    shuffle=True)

# Data Pipeline
def resize_image(image, label):
    image = tf.image.resize(image, [224, 224])
    return image, label

ds_train = (
    ds_train_
    .map(resize_image)
    .cache()
)
ds_valid = (
    ds_valid_
    .map(resize_image)
    .cache()
)

plt.figure(figsize=(10, 10))
for images, labels in ds_train_.take(1):
  for i in range(8):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(i)
    plt.axis("off")
# Out:
# Found 40 files belonging to 2 classes.
# Using 32 files for training.
# Found 40 files belonging to 2 classes.
# Using 8 files for validation.

# %%
data_augmentation = keras.Sequential([            
  keras.layers.RandomFlip("horizontal_and_vertical"),
  keras.layers.RandomRotation(0.9),
  keras.layers.RandomZoom(.5, .5)
])

# train_datagen = keras.preprocessing.image.ImageDataGenerator(
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True)


# def augmentate_image(image, label):
#     image = tf.image.random_flip_left_right(image)
#     image = tf.image.random_crop(image, size=(224, 224))
#     return image, label

# ds_train_augmented = (
#     ds_train
#     .map(augmentate_image)
#     .cache()
# )

# plt.figure(figsize=(10, 10))
# for images, labels in ds_train_augmented.take(1):
#   for i in range(8):
#     ax = plt.subplot(3, 3, i + 1)
#     plt.imshow(images[i].numpy().astype("uint8"))
#     plt.title(i)
#     plt.axis("off")

# %%
base_model = keras.applications.ResNet50(weights='imagenet', include_top=False)
base_model.trainable = False
#base_model.summary()

# %%
model = keras.Sequential([
    data_augmentation,
    base_model,
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(.4),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
initial_learning_rate = 0.01
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=5,
    decay_rate=0.96,
    staircase=True)

model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
  loss="binary_crossentropy",
  metrics=['accuracy'])


history = model.fit(
  ds_train,
  validation_data=ds_valid,
  epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 8s 360ms/step - loss: 0.8200 - accuracy: 0.5312 - val_loss: 12.4256 - val_accuracy: 0.5000
# Epoch 2/200
# 4/4 [==============================] - 0s 69ms/step - loss: 0.5791 - accuracy: 0.7812 - val_loss: 7.8585 - val_accuracy: 0.5000
# Epoch 3/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6905 - accuracy: 0.6250 - val_loss: 8.1668 - val_accuracy: 0.5000
# Epoch 4/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5130 - accuracy: 0.7812 - val_loss: 7.5369 - val_accuracy: 0.5000
# Epoch 5/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.4775 - accuracy: 0.7812 - val_loss: 6.0584 - val_accuracy: 0.5000
# Epoch 6/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.5125 - accuracy: 0.7500 - val_loss: 3.6963 - val_accuracy: 0.5000
# Epoch 7/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3301 - accuracy: 0.8438 - val_loss: 2.6771 - val_accuracy: 0.6250
# Epoch 8/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.3116 - accuracy: 0.8750 - val_loss: 2.1547 - val_accuracy: 0.6250
# Epoch 9/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2669 - accuracy: 0.8750 - val_loss: 1.9572 - val_accuracy: 0.6250
# Epoch 10/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.4434 - accuracy: 0.7812 - val_loss: 1.6656 - val_accuracy: 0.6250
# Epoch 11/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3596 - accuracy: 0.8125 - val_loss: 1.4665 - val_accuracy: 0.6250
# Epoch 12/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.3826 - accuracy: 0.8438 - val_loss: 1.1954 - val_accuracy: 0.7500
# Epoch 13/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1195 - accuracy: 0.9688 - val_loss: 1.0651 - val_accuracy: 0.7500
# Epoch 14/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.2397 - accuracy: 0.9062 - val_loss: 1.0376 - val_accuracy: 0.7500
# Epoch 15/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2147 - accuracy: 0.9062 - val_loss: 1.0413 - val_accuracy: 0.7500
# Epoch 16/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0998 - accuracy: 0.9688 - val_loss: 1.0398 - val_accuracy: 0.7500
# Epoch 17/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1625 - accuracy: 0.9688 - val_loss: 1.0375 - val_accuracy: 0.7500
# Epoch 18/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0821 - accuracy: 0.9688 - val_loss: 1.0459 - val_accuracy: 0.7500
# Epoch 19/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3644 - accuracy: 0.8438 - val_loss: 1.0073 - val_accuracy: 0.7500
# Epoch 20/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1063 - accuracy: 0.9062 - val_loss: 0.9554 - val_accuracy: 0.7500
# Epoch 21/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0902 - accuracy: 1.0000 - val_loss: 0.8781 - val_accuracy: 0.7500
# Epoch 22/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1182 - accuracy: 0.9375 - val_loss: 0.8516 - val_accuracy: 0.7500
# Epoch 23/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.1229 - accuracy: 0.9688 - val_loss: 0.8135 - val_accuracy: 0.7500
# Epoch 24/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.2356 - accuracy: 0.8750 - val_loss: 0.7442 - val_accuracy: 0.8750
# Epoch 25/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1274 - accuracy: 0.9375 - val_loss: 0.7668 - val_accuracy: 0.8750
# Epoch 26/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2904 - accuracy: 0.8750 - val_loss: 0.8387 - val_accuracy: 0.8750
# Epoch 27/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0931 - accuracy: 0.9688 - val_loss: 0.8599 - val_accuracy: 0.8750
# Epoch 28/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0827 - accuracy: 0.9688 - val_loss: 0.8579 - val_accuracy: 0.8750
# Epoch 29/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 0.8384 - val_accuracy: 0.8750
# Epoch 30/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1289 - accuracy: 0.8750 - val_loss: 0.8145 - val_accuracy: 0.8750
# Epoch 31/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.8084 - val_accuracy: 0.8750
# Epoch 32/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1358 - accuracy: 0.9688 - val_loss: 0.8059 - val_accuracy: 0.8750
# Epoch 33/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.1536 - accuracy: 0.9062 - val_loss: 0.8199 - val_accuracy: 0.8750
# Epoch 34/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.8222 - val_accuracy: 0.8750
# Epoch 35/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0788 - accuracy: 0.9688 - val_loss: 0.8069 - val_accuracy: 0.8750
# Epoch 36/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.7980 - val_accuracy: 0.8750
# Epoch 37/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0857 - accuracy: 0.9688 - val_loss: 0.7436 - val_accuracy: 0.8750
# Epoch 38/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0961 - accuracy: 0.9688 - val_loss: 0.6898 - val_accuracy: 0.8750
# Epoch 39/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0653 - accuracy: 0.9688 - val_loss: 0.6474 - val_accuracy: 0.8750
# Epoch 40/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.6308 - val_accuracy: 0.8750
# Epoch 41/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.6137 - val_accuracy: 0.8750
# Epoch 42/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1709 - accuracy: 0.9062 - val_loss: 0.6118 - val_accuracy: 0.8750
# Epoch 43/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1044 - accuracy: 0.9688 - val_loss: 0.6482 - val_accuracy: 0.8750
# Epoch 44/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.6531 - val_accuracy: 0.8750
# Epoch 45/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.1324 - accuracy: 0.9375 - val_loss: 0.6406 - val_accuracy: 0.8750
# Epoch 46/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.6313 - val_accuracy: 0.8750
# Epoch 47/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.6275 - val_accuracy: 0.8750
# Epoch 48/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.6230 - val_accuracy: 0.8750
# Epoch 49/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0941 - accuracy: 0.9375 - val_loss: 0.6268 - val_accuracy: 0.8750
# Epoch 50/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.6359 - val_accuracy: 0.8750
# Epoch 51/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.6305 - val_accuracy: 0.8750
# Epoch 52/200
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.6172 - val_accuracy: 0.8750
# Epoch 53/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0426 - accuracy: 0.9688 - val_loss: 0.6122 - val_accuracy: 0.8750
# Epoch 54/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.6090 - val_accuracy: 0.8750
# Epoch 55/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.8750
# Epoch 56/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.6022 - val_accuracy: 0.8750
# Epoch 57/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.5921 - val_accuracy: 0.8750
# Epoch 58/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.5717 - val_accuracy: 0.8750
# Epoch 59/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0502 - accuracy: 0.9688 - val_loss: 0.5419 - val_accuracy: 0.8750
# Epoch 60/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0581 - accuracy: 0.9688 - val_loss: 0.5238 - val_accuracy: 0.8750
# Epoch 61/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.8750
# Epoch 62/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.8750
# Epoch 63/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.8750
# Epoch 64/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0695 - accuracy: 0.9688 - val_loss: 0.5004 - val_accuracy: 0.8750
# Epoch 65/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.4916 - val_accuracy: 0.8750
# Epoch 66/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0905 - accuracy: 0.9688 - val_loss: 0.4956 - val_accuracy: 0.8750
# Epoch 67/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.8750
# Epoch 68/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.8750
# Epoch 69/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.5078 - val_accuracy: 0.8750
# Epoch 70/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0319 - accuracy: 0.9688 - val_loss: 0.5043 - val_accuracy: 0.8750
# Epoch 71/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.8750
# Epoch 72/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.8750
# Epoch 73/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4885 - val_accuracy: 0.8750
# Epoch 74/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4838 - val_accuracy: 0.8750
# Epoch 75/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.8750
# Epoch 76/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.4666 - val_accuracy: 0.8750
# Epoch 77/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4620 - val_accuracy: 0.8750
# Epoch 78/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.8750
# Epoch 79/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0543 - accuracy: 0.9688 - val_loss: 0.4610 - val_accuracy: 0.8750
# Epoch 80/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4552 - val_accuracy: 0.8750
# Epoch 81/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.4518 - val_accuracy: 0.8750
# Epoch 82/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0956 - accuracy: 0.9375 - val_loss: 0.4499 - val_accuracy: 0.8750
# Epoch 83/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1779 - accuracy: 0.9375 - val_loss: 0.4506 - val_accuracy: 0.8750
# Epoch 84/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.4613 - val_accuracy: 0.8750
# Epoch 85/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.8750
# Epoch 86/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0512 - accuracy: 0.9688 - val_loss: 0.4568 - val_accuracy: 0.8750
# Epoch 87/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.4577 - val_accuracy: 0.8750
# Epoch 88/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.4599 - val_accuracy: 0.8750
# Epoch 89/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0361 - accuracy: 0.9688 - val_loss: 0.4603 - val_accuracy: 0.8750
# Epoch 90/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0486 - accuracy: 0.9688 - val_loss: 0.4587 - val_accuracy: 0.8750
# Epoch 91/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0637 - accuracy: 0.9688 - val_loss: 0.4529 - val_accuracy: 0.8750
# Epoch 92/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.8750
# Epoch 93/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0425 - accuracy: 0.9688 - val_loss: 0.4449 - val_accuracy: 0.8750
# Epoch 94/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0411 - accuracy: 0.9688 - val_loss: 0.4401 - val_accuracy: 0.8750
# Epoch 95/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.4395 - val_accuracy: 0.8750
# Epoch 96/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.4408 - val_accuracy: 0.8750
# Epoch 97/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.8750
# Epoch 98/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.8750
# Epoch 99/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8750
# Epoch 100/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.4511 - val_accuracy: 0.8750
# Epoch 101/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.8750
# Epoch 102/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.4538 - val_accuracy: 0.8750
# Epoch 103/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0892 - accuracy: 0.9688 - val_loss: 0.4445 - val_accuracy: 0.8750
# Epoch 104/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.4377 - val_accuracy: 0.8750
# Epoch 105/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4321 - val_accuracy: 0.8750
# Epoch 106/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.4289 - val_accuracy: 0.8750
# Epoch 107/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.8750
# Epoch 108/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0451 - accuracy: 0.9688 - val_loss: 0.4249 - val_accuracy: 0.8750
# Epoch 109/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.8750
# Epoch 110/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8750
# Epoch 111/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.8750
# Epoch 112/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.8750
# Epoch 113/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0456 - accuracy: 0.9688 - val_loss: 0.4109 - val_accuracy: 0.8750
# Epoch 114/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.8750
# Epoch 115/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.4119 - val_accuracy: 0.8750
# Epoch 116/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.8750
# Epoch 117/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.8750
# Epoch 118/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4054 - val_accuracy: 0.8750
# Epoch 119/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.3994 - val_accuracy: 0.8750
# Epoch 120/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.3931 - val_accuracy: 0.8750
# Epoch 121/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.8750
# Epoch 122/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0747 - accuracy: 0.9688 - val_loss: 0.3921 - val_accuracy: 0.8750
# Epoch 123/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0643 - accuracy: 0.9688 - val_loss: 0.3943 - val_accuracy: 0.8750
# Epoch 124/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8750
# Epoch 125/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3981 - val_accuracy: 0.8750
# Epoch 126/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.8750
# Epoch 127/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.3976 - val_accuracy: 0.8750
# Epoch 128/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3984 - val_accuracy: 0.8750
# Epoch 129/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.3997 - val_accuracy: 0.8750
# Epoch 130/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4014 - val_accuracy: 0.8750
# Epoch 131/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4016 - val_accuracy: 0.8750
# Epoch 132/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.4015 - val_accuracy: 0.8750
# Epoch 133/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0616 - accuracy: 0.9688 - val_loss: 0.4006 - val_accuracy: 0.8750
# Epoch 134/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4025 - val_accuracy: 0.8750
# Epoch 135/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4054 - val_accuracy: 0.8750
# Epoch 136/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.4067 - val_accuracy: 0.8750
# Epoch 137/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.4063 - val_accuracy: 0.8750
# Epoch 138/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.4056 - val_accuracy: 0.8750
# Epoch 139/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.4076 - val_accuracy: 0.8750
# Epoch 140/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.4066 - val_accuracy: 0.8750
# Epoch 141/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4090 - val_accuracy: 0.8750
# Epoch 142/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0564 - accuracy: 0.9688 - val_loss: 0.4051 - val_accuracy: 0.8750
# Epoch 143/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4059 - val_accuracy: 0.8750
# Epoch 144/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4081 - val_accuracy: 0.8750
# Epoch 145/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4074 - val_accuracy: 0.8750
# Epoch 146/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4108 - val_accuracy: 0.8750
# Epoch 147/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.4117 - val_accuracy: 0.8750
# Epoch 148/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.4119 - val_accuracy: 0.8750
# Epoch 149/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.4118 - val_accuracy: 0.8750
# Epoch 150/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0947 - accuracy: 0.9688 - val_loss: 0.4125 - val_accuracy: 0.8750
# Epoch 151/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4114 - val_accuracy: 0.8750
# Epoch 152/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0309 - accuracy: 0.9688 - val_loss: 0.4105 - val_accuracy: 0.8750
# Epoch 153/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.8750
# Epoch 154/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.8750
# Epoch 155/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.8750
# Epoch 156/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.4169 - val_accuracy: 0.8750
# Epoch 157/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.8750
# Epoch 158/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.8750
# Epoch 159/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.8750
# Epoch 160/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.4186 - val_accuracy: 0.8750
# Epoch 161/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4187 - val_accuracy: 0.8750
# Epoch 162/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.8750
# Epoch 163/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.4182 - val_accuracy: 0.8750
# Epoch 164/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4191 - val_accuracy: 0.8750
# Epoch 165/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.8750
# Epoch 166/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4159 - val_accuracy: 0.8750
# Epoch 167/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.8750
# Epoch 168/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4160 - val_accuracy: 0.8750
# Epoch 169/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0332 - accuracy: 0.9688 - val_loss: 0.4178 - val_accuracy: 0.8750
# Epoch 170/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0357 - accuracy: 0.9688 - val_loss: 0.4156 - val_accuracy: 0.8750
# Epoch 171/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4159 - val_accuracy: 0.8750
# Epoch 172/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.4155 - val_accuracy: 0.8750
# Epoch 173/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.4141 - val_accuracy: 0.8750
# Epoch 174/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0665 - accuracy: 0.9375 - val_loss: 0.4143 - val_accuracy: 0.8750
# Epoch 175/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4159 - val_accuracy: 0.8750
# Epoch 176/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.4140 - val_accuracy: 0.8750
# Epoch 177/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.8750
# Epoch 178/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.8750
# Epoch 179/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4147 - val_accuracy: 0.8750
# Epoch 180/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.4146 - val_accuracy: 0.8750
# Epoch 181/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4169 - val_accuracy: 0.8750
# Epoch 182/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.8750
# Epoch 183/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4142 - val_accuracy: 0.8750
# Epoch 184/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4142 - val_accuracy: 0.8750
# Epoch 185/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.4141 - val_accuracy: 0.8750
# Epoch 186/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.8750
# Epoch 187/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.8750
# Epoch 188/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.8750
# Epoch 189/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.8750
# Epoch 190/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.8750
# Epoch 191/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4168 - val_accuracy: 0.8750
# Epoch 192/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4150 - val_accuracy: 0.8750
# Epoch 193/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.8750
# Epoch 194/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4133 - val_accuracy: 0.8750
# Epoch 195/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.4114 - val_accuracy: 0.8750
# Epoch 196/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0473 - accuracy: 0.9688 - val_loss: 0.4129 - val_accuracy: 0.8750
# Epoch 197/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.8750
# Epoch 198/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4141 - val_accuracy: 0.8750
# Epoch 199/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1298 - accuracy: 0.9688 - val_loss: 0.4125 - val_accuracy: 0.8750
# Epoch 200/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.8750

# %%
import pandas as pd

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot();

# %%
ds_test_ = keras.preprocessing.image_dataset_from_directory(
    "/content/plates/test/", 
    image_size=[256, 341],
    shuffle=False
)

ds_test = (
    ds_test_
    .map(resize_image)
    .cache()
)
# Out:
# Found 744 files belonging to 1 classes.

# %%
prediction = model.predict(ds_test)

# %%
test_prediction = [prediction[i][0] for i in range(len(prediction))]
submission_df = pd.DataFrame.from_dict({'id': ds_test_.file_paths, 'label': test_prediction})

# %%
submission_df['label'] = submission_df['label'].map(lambda pred: 'dirty' if pred > 0.5 else 'cleaned')
submission_df['id'] = submission_df['id'].str.replace('/content/plates/test/unknown/', '')
submission_df['id'] = submission_df['id'].str.replace('.jpg', '')
submission_df.set_index('id', inplace=True)

submission_df.head(n=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       label
# id
# 0000  dirty
# 0001  dirty
# 0002  dirty
# 0003  dirty
# 0004  dirty
# 0005  dirty
# 0006  dirty
# 0007  dirty
# 0008  dirty
# 0009  dirty

# %%
submission_df.to_csv('submission.csv')

# %%
ds_train_all_ = keras.preprocessing.image_dataset_from_directory(
    "/content/plates/train/", 
    image_size=[256, 341],
    shuffle=False
)

ds_train_all = (
    ds_train_all_
    .map(resize_image)
    .cache()
)
# Out:
# Found 40 files belonging to 2 classes.

# %%
prediction_train_all = model.predict(ds_train_all)

# %%
train_prediction = [prediction_train_all[i][0] for i in range(len(prediction_train_all))]
submission_df = pd.DataFrame.from_dict({'id': ds_train_all_.file_paths, 'label': train_prediction})

submission_df['label'] = submission_df['label'].map(lambda pred: 'dirty' if pred > 0.5 else 'cleaned')
submission_df['id'] = submission_df['id'].str.replace('/content/plates/test/unknown/', '')
submission_df['id'] = submission_df['id'].str.replace('.jpg', '')
submission_df.set_index('id', inplace=True)

submission_df.head(n=40)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#                                       label
# id
# /content/plates/train/cleaned/0000  cleaned
# /content/plates/train/cleaned/0001  cleaned
# /content/plates/train/cleaned/0002  cleaned
# /content/plates/train/cleaned/0003  cleaned
# /content/plates/train/cleaned/0004  cleaned
# /content/plates/train/cleaned/0005  cleaned
# /content/plates/train/cleaned/0006  cleaned
# /content/plates/train/cleaned/0007  cleaned
# /content/plates/train/cleaned/0008  cleaned
# /content/plates/train/cleaned/0009  cleaned
# /content/plates/train/cleaned/0010  cleaned
# /content/plates/train/cleaned/0011  cleaned
# /content/plates/train/cleaned/0012  cleaned
# /content/plates/train/cleaned/0013  cleaned
# /content/plates/train/cleaned/0014  cleaned
# /content/plates/train/cleaned/0015  cleaned
# /content/plates/train/cleaned/0016  cleaned
# /content/plates/train/cleaned/0017  cleaned
# /content/plates/train/cleaned/0018  cleaned
# /content/plates/train/cleaned/0019  cleaned
# /content/plates/train/dirty/0000    cleaned
# /content/plates/train/dirty/0001      dirty
# /content/plates/train/dirty/0002      dirty
# /content/plates/train/dirty/0003      dirty
# /content/plates/train/dirty/0004      dirty
# /content/plates/train/dirty/0005      dirty
# /content/plates/train/dirty/0006      dirty
# /content/plates/train/dirty/0007      dirty
# /content/plates/train/dirty/0008      dirty
# /content/plates/train/dirty/0009      dirty
# /content/plates/train/dirty/0010      dirty
# /content/plates/train/dirty/0011      dirty
# /content/plates/train/dirty/0012      dirty
# /content/plates/train/dirty/0013      dirty
# /content/plates/train/dirty/0014      dirty
# /content/plates/train/dirty/0015      dirty
# /content/plates/train/dirty/0016      dirty
# /content/plates/train/dirty/0017      dirty
# /content/plates/train/dirty/0018      dirty
# /content/plates/train/dirty/0019      dirty
